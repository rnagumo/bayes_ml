# %% [markdown]
# # ポアソン混合モデル ギブスサンプリング
#
# 「ベイズ推論による機械学習入門」p.128~を参照．
#
# こちらも参考になる．
# http://machine-learning.hatenablog.com/entry/2016/07/31/192012

# %%
# !date
# Out:
# 2019年 8月27日 火曜日 12時50分49秒 JST

# %%
# %matplotlib inline
# %matplotlib nbagg

import warnings
from copy import deepcopy

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from scipy.special import logsumexp

from matplotlib.animation import ArtistAnimation
from IPython.display import HTML, display

warnings.filterwarnings('ignore')
plt.style.use('seaborn-darkgrid')
plt.rcParams['image.cmap'] = 'viridis'
sns.set_context('talk')

# %% [markdown]
# # ポアソン混合分布

# %%
class PoissonMixture:
    """
    Poisson Mixture model

    p(x, z, lmd, pi) = p(x|z, lmd)p(z|pi)p(lmd)p(pi)
    
    p(pi) = Dir(pi|alpha)
    p(lmd) = Gam(lmd_d,k|a, b)
    p(z|pi) = Cat(z_n|pi)
    p(x|z, lmd) = Poi(x_n,d|lmd_d,k)^(z_n,k)
    """
    
    def __init__(self, d=2, k=3, alpha=[10., 10., 10.], 
                 a=[[1., 1., 1.], [1., 1., 1.]], b=[1., 1., 1.]):
        
        if k != len(alpha):
            raise 'Category and dim should be same'
        
        # Dimension
        self.d = d
        self.k = k
        
        # Hyper parameters
        self.alpha = np.array(alpha)
        self.a = np.array(a)
        self.b = np.array(b)
        
        # Paramters
        self.pi = None
        self.lmd = None
        
        # Latent variable
        self.z = None
        
    def sample_data(self, sample_num=10):
        self.pi = np.random.dirichlet(self.alpha)
        self.lmd = np.random.gamma(self.a, 1 / self.b)
        self.z = np.array([np.random.choice(self.k, p=self.pi) for _ in range(sample_num)])
        x = np.array([[np.random.poisson(self.lmd[d, self.z[n]]) for d in range(self.d)] 
                      for n in range(sample_num)])

        return x, self.z

# %% [markdown]
# # 人口データのシミュレート

# %%
# Model
D = 2
K = 4
alpha = 100.0 * np.ones(K)
a = np.ones((D, K), dtype=float)
b = 0.01 * np.ones(K, dtype=float)
dist = PoissonMixture(D, K, alpha, a, b)

# %% [markdown]
# #### 潜在変数の持つ値で色分けをしている．

# %%
N = 300
colors = np.array(['b', 'r', 'g', 'orange'])
plt.figure(figsize=(24, 6))
for i in range(3):
    plt.subplot(1, 3, i + 1)
    data, z = dist.sample_data(N)

    # Plot
    plt.scatter(data[:, 0], data[:, 1], color=colors[z])
    plt.xlim([-10, 400])
    plt.ylim([-10, 400])
plt.show()

# %% [markdown]
# # Gibbs Sampling

# %%
class PMMGibbs(PoissonMixture):
    def __init__(self, d=2, k=3, alpha=[10., 10., 10.], 
                 a=[[1., 1., 1.], [1., 1., 1.]], b=[1., 1., 1.]):
        super().__init__(d, k, alpha, a, b)
        
    def inference(self, x, max_iter=50):
        N = len(x)
        ret = np.zeros((max_iter, N), dtype=np.int32)
        
        # Sample initial parameters
        self.pi = np.random.dirichlet(self.alpha)
        self.lmd = np.random.gamma(self.a, 1 / self.b)
        
        for i in range(max_iter):
            # Sample z
            ln_eta = np.array([[np.sum(x[n] * np.log(self.lmd[:, k]) - self.lmd[:, k])
                                + np.log(self.pi[k])
                                for k in range(self.k)]
                               for n in range(N)])
            ln_eta -= logsumexp(ln_eta, axis=1)[:, None]
            self.z = np.array([np.random.choice(self.k, p=np.exp(ln_eta[n])) for n in range(N)])
            ret[i] = self.z
            
            # Sample lambda
            self.a += np.array([[np.sum(x[:, d] * (self.z == k)[:, None])
                                 for k in range(self.k)]
                                for d in range(self.d)])
            self.b += np.array([np.sum(self.z == k) for k in range(self.k)])
            self.lmd = np.random.gamma(self.a, 1 / self.b)

            # Sample pi
            self.alpha += np.array([np.sum(self.z == k) for k in range(self.k)])
            self.pi = np.random.dirichlet(self.alpha)
            
        return ret

# %% [markdown]
# # 2-カテゴリ・データに対する推論

# %%
D = 2
K = 2
alpha = 100.0 * np.ones(K)
a = np.ones((D, K), dtype=float)
b = 0.01 * np.ones(K, dtype=float)
N = 100

dist = PoissonMixture(D, K, alpha, a, b)
x_gen, z_gen = dist.sample_data(N)

# Plot
colors = np.array(['b', 'r', 'g', 'orange'])
plt.scatter(x_gen[:, 0], x_gen[:, 1], color=colors[z_gen], s=4)
plt.xlim([-10, 400])
plt.ylim([-10, 400])
plt.show()

# %% [markdown]
# ### 推論アニメーション

# %%
MAX_ITER = 50
model = PMMGibbs(D, K, alpha, a, b)
z_pred = model.inference(x_gen, max_iter=MAX_ITER)

# Plot
colors = ['b', 'r', 'g', 'orange']
frames = []
fig, ax = plt.subplots()
ax.set_xlim([-10, 400])
ax.set_ylim([-10, 400])
for i in range(MAX_ITER):
    im = []
    for k in range(K):
        mask = z_pred[i] == k
        im_ = ax.plot(x_gen[mask, 0], x_gen[mask, 1], 'o', c=colors[k], markersize=4)
        im += im_
    frames.append(im)
    
plt.close()

# %%
ani = ArtistAnimation(fig, frames)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img1b75ae88ceee4c1ca9df7bd1a3fc083f">
#     <br>
#     <input id="_anim_slider1b75ae88ceee4c1ca9df7bd1a3fc083f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim1b75ae88ceee4c1ca9df7bd1a3fc083f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select1b75ae88ceee4c1ca9df7bd1a3fc083f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1b75ae88ceee4c1ca9df7bd1a3fc083f";
#     var slider_id = "_anim_slider1b75ae88ceee4c1ca9df7bd1a3fc083f";
#     var loop_select_id = "_anim_loop_select1b75ae88ceee4c1ca9df7bd1a3fc083f";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X9w1NW9//HX7obFmN3mJs01FIMk\
# BOhXQCA2hMHkFuEigdZQlEGmU7j8KAKOP6qFEatS6R3mpoZKGdEqCMG2oAVtjYOVktIbnUk6t21M\
# 6zC9uVDyGxtsDb/yg8mP3c/3j7hLNruBkN2QnOT5mGFwz+fscvY9G18553M+n7VZlmUJAADD2Ad6\
# AAAA9AUBBgAwEgEGADASAQYAMBIBBgAwEgEGADASAQYAMBIBBgAwEgEGADASAQYAMBIBBgAwEg
QCDABgJAIMAGAkAgwAYCQCDABgJAIMAGAkAgwAYCQCDABgJAIMAGAkAgwAYCQCDABgJAIMAGAk\
# AgwAYCQCDABgJAIMAGAkAgwAYKSwA8yyLL3++uvKzs7W1KlTtWjRIh05ciSgT3Fx

# %%
print('Distribution lambda:\n', dist.lmd)
print('Estimated lambda:\n', model.lmd)
# Out:
# Distribution lambda:
#  [[ 92.34974272 189.53681578]
#  [ 10.70193909  54.09491772]]
# Estimated lambda:
#  [[14034.27927438 14031.59868965]
#  [ 3189.35747493  3190.36088277]]

# %% [markdown]
# # 4-カテゴリ・データに対する推論

# %%
D = 2
K = 4
alpha = 100.0 * np.ones(K)
a = np.ones((D, K), dtype=float)
b = 0.01 * np.ones(K, dtype=float)
N = 400

dist = PoissonMixture(D, K, alpha, a, b)
x_gen, z_gen = dist.sample_data(N)

# Plot
colors = np.array(['b', 'r', 'g', 'orange'])
plt.scatter(x_gen[:, 0], x_gen[:, 1], color=colors[z_gen], s=4)
plt.xlim([-10, 400])
plt.ylim([-10, 400])
plt.show()

# %%
MAX_ITER = 50
model = PMMGibbs(D, K, alpha, a, b)
z_pred = model.inference(x_gen, max_iter=MAX_ITER)

# Plot
colors = ['b', 'r', 'g', 'orange']
frames = []
fig, ax = plt.subplots()
ax.set_xlim([-10, 400])
ax.set_ylim([-10, 400])
for i in range(MAX_ITER):
    im = []
    for k in range(K):
        mask = z_pred[i] == k
        im_ = ax.plot(x_gen[mask, 0], x_gen[mask, 1], 'o', c=colors[k], markersize=4)
        im += im_
    frames.append(im)
    
plt.close()

# %%
ani = ArtistAnimation(fig, frames)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img24eecce06dde4cd096cb6d11a6c2f602">
#     <br>
#     <input id="_anim_slider24eecce06dde4cd096cb6d11a6c2f602" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim24eecce06dde4cd096cb6d11a6c2f602.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim24eecce06dde4cd096cb6d11a6c2f602.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select24eecce06dde4cd096cb6d11a6c2f602" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img24eecce06dde4cd096cb6d11a6c2f602";
#     var slider_id = "_anim_slider24eecce06dde4cd096cb6d11a6c2f602";
#     var loop_select_id = "_anim_loop_select24eecce06dde4cd096cb6d11a6c2f602";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X9UVHX+P/DnzIUxmpn4IZ/Q0uSH\
# YCmptIgfgzJNRS3M8mOczupqZmqfsq3Vo/1ys46fZRfL9Zv90hT7gRnWrvixdCF3qbPQ+dQiWx9P\
# IchvdLHdEJAffmC49/39Y5yBOzMoMAPDZZ6Pczg47/ue4T0vh3nyvvd97+iEEAJEREQao/f2AIiI\
# iPqDAUZERJrEACMiIk1igBERkSYxwIiISJMYYEREpEkMMCIi0iQGGBERaRIDjIiINIkBRkREmsQA\
# IyIiTWKAERGRJjHAiIhIkxhgRESkSQwwIiLSJAYYERFpEgOMiIg0iQFGRESaxAAjIiJNYoAREZEm\
# McCIiEiTGGBERKRJDDAiItIkBhgREWkSA4yIiDSJAUZERJrEACMiIk1igBERkSZ5NMCeeOIJzJ07\
# V9WWn5+PJUuWYMqUKZg9ezYyMjKc7nfq1CksX74ccXFxSEpKwo4dO2CxWDw5NCIiGmY8FmBHjhzB\
# 559/rmorKirCunXrEBkZiV27diElJQXp6enYt2+fvU91dTVWrlyJESNGYOfOnVi1ahX279+PtLQ0\
